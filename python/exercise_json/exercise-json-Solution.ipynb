# %%
# This exercise will focus on parsing data in json format.
# We are accessing the Ebay API to perform a search for 'iphone', and we want to compile just some 
# of the returned information in another json file.
# First we'll import the necessary modules:
import json
from api import get_data # this is not a python module! It's our api.py file.
import os
import pprint # used to pretty print big python dictionaries

# Now we'll call the external API using a function in our api.py file
source = get_data("https://svcs.ebay.com/services/search/FindingService/v1?OPERATION-NAME=findItemsByKeywords&SERVICE-VERSION=1.0.0&RESPONSE-DATA-FORMAT=JSON&callback=_cb_findItemsByKeywords&REST-PAYLOAD&keywords=iPhone&paginationInput.entriesPerPage=6&GLOBAL-ID=EBAY-US&siteid=0&SECURITY-APPNAME=xotikota-pythonpo-PRD-87f3df848-3e35dfb4")
print(source)
# Out:
# b'/**/_cb_findItemsByKeywords({"findItemsByKeywordsResponse":[{"ack":["Success"],"version":["1.13.0"],"timestamp":["2018-12-21T13:57:52.347Z"],"searchResult":[{"@count":"6","item":[{"itemId":["382231636268"],"title":["Apple iPhone 7 32\\/128\\/256GB Factory Unlocked AT&T Sprint Verizon T-Mobile"],"globalId":["EBAY-US"],"subtitle":["US SELLER - 12 MONTH WARRANTY - FREE SHIPPING!"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32-128-256GB-Factory-Unlocked-AT-T-Sprint-Verizon-T-Mobile-\\/382231636268?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["30101"],"location":["Acworth,GA,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["false"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"234.99"}],"convertedCurrentPrice":[{"@currencyId":"USD","__value__":"234.99"}],"sellingState":["Active"],"timeLeft":["P22DT23H11M57S"]}],"listingInfo":[{"bestOfferEnabled":["false"],"buyItNowAvailable":["false"],"startTime":["2017-09-20T13:09:49.000Z"],"endTime":["2019-01-13T13:09:49.000Z"],"listingType":["FixedPrice"],"gift":["false"],"watchCount":["5868"]}],"returnsAccepted":["true"],"condition":[{"conditionId":["2500"],"conditionDisplayName":["Seller refurbished"]}],"isMultiVariationListing":["true"],"topRatedListing":["false"]},{"itemId":["352381131997"],"title":["Apple iPhone 7 GSM (Unlocked) Verizon AT&T TMobile Sprint 32GB 128GB 256GB"],"globalId":["EBAY-US"],"subtitle":["Free Shipping | 60 Day Warranty | #1 Customer Service"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-GSM-Unlocked-Verizon-AT-T-TMobile-Sprint-32GB-128GB-256GB-\\/352381131997?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["20879"],"location":["Gaithersburg,MD,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["true"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"249.89"}],"convertedCurrentPrice":[{"@currencyId":"USD","__value__":"249.89"}],"sellingState":["Active"],"timeLeft":["P21DT0H7M23S"]}],"listingInfo":[{"bestOfferEnabled":["false"],"buyItNowAvailable":["false"],"startTime":["2018-06-15T14:05:15.000Z"],"endTime":["2019-01-11T14:05:15.000Z"],"listingType":["FixedPrice"],"gift":["false"],"watchCount":["944"]}],"returnsAccepted":["true"],"condition":[{"conditionId":["2500"],"conditionDisplayName":["Seller refurbished"]}],"isMultiVariationListing":["true"],"topRatedListing":["true"]},{"itemId":["252764834267"],"title":["Apple iPhone 7 32GB GSM Unlocked Smartphone"],"globalId":["EBAY-US"],"subtitle":["TOP SELLER - FREE SHIPPING - FREE ACCESSORIES"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32GB-GSM-Unlocked-Smartphone-\\/252764834267?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["11103"],"location":["Astoria,NY,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["true"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"279.99"}],"convertedCurrentPrice":[{"@currencyId":"U ...

# %%
# Let's clean the outcome and turn it into a valid json object:
x = str(source)
cleaned_source = str(x[:-2]).replace("b'/**/_cb_findItemsByKeywords(", "")
# Let's get a glimpse of the outcome:
print(cleaned_source)
# Out:
# {"findItemsByKeywordsResponse":[{"ack":["Success"],"version":["1.13.0"],"timestamp":["2018-12-21T13:57:52.347Z"],"searchResult":[{"@count":"6","item":[{"itemId":["382231636268"],"title":["Apple iPhone 7 32\\/128\\/256GB Factory Unlocked AT&T Sprint Verizon T-Mobile"],"globalId":["EBAY-US"],"subtitle":["US SELLER - 12 MONTH WARRANTY - FREE SHIPPING!"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32-128-256GB-Factory-Unlocked-AT-T-Sprint-Verizon-T-Mobile-\\/382231636268?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["30101"],"location":["Acworth,GA,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["false"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"234.99"}],"convertedCurrentPrice":[{"@currencyId":"USD","__value__":"234.99"}],"sellingState":["Active"],"timeLeft":["P22DT23H11M57S"]}],"listingInfo":[{"bestOfferEnabled":["false"],"buyItNowAvailable":["false"],"startTime":["2017-09-20T13:09:49.000Z"],"endTime":["2019-01-13T13:09:49.000Z"],"listingType":["FixedPrice"],"gift":["false"],"watchCount":["5868"]}],"returnsAccepted":["true"],"condition":[{"conditionId":["2500"],"conditionDisplayName":["Seller refurbished"]}],"isMultiVariationListing":["true"],"topRatedListing":["false"]},{"itemId":["352381131997"],"title":["Apple iPhone 7 GSM (Unlocked) Verizon AT&T TMobile Sprint 32GB 128GB 256GB"],"globalId":["EBAY-US"],"subtitle":["Free Shipping | 60 Day Warranty | #1 Customer Service"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-GSM-Unlocked-Verizon-AT-T-TMobile-Sprint-32GB-128GB-256GB-\\/352381131997?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["20879"],"location":["Gaithersburg,MD,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["true"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"249.89"}],"convertedCurrentPrice":[{"@currencyId":"USD","__value__":"249.89"}],"sellingState":["Active"],"timeLeft":["P21DT0H7M23S"]}],"listingInfo":[{"bestOfferEnabled":["false"],"buyItNowAvailable":["false"],"startTime":["2018-06-15T14:05:15.000Z"],"endTime":["2019-01-11T14:05:15.000Z"],"listingType":["FixedPrice"],"gift":["false"],"watchCount":["944"]}],"returnsAccepted":["true"],"condition":[{"conditionId":["2500"],"conditionDisplayName":["Seller refurbished"]}],"isMultiVariationListing":["true"],"topRatedListing":["true"]},{"itemId":["252764834267"],"title":["Apple iPhone 7 32GB GSM Unlocked Smartphone"],"globalId":["EBAY-US"],"subtitle":["TOP SELLER - FREE SHIPPING - FREE ACCESSORIES"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32GB-GSM-Unlocked-Smartphone-\\/252764834267?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["11103"],"location":["Astoria,NY,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["true"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"279.99"}],"convertedCurrentPrice":[{"@currencyId":"USD","__value__":"279.99"}],"se ...

# %%
# Let's save the outcome into a json file, so that we can inspect it (you wouldn't do this on a production environment, but it helps a lot when developing):
with open("outcome.json", "w") as json_file:
    print(cleaned_source, file=json_file)

# %%
# Try to open the file. Whoa! The json has an error! Let's find it using an online tool: https://jsoneditoronline.org/
# We found the error, so let's fix it (not in our file, but in our cleaned_source variable):
cleaned_source = cleaned_source.replace('\\\\"', '')
print(cleaned_source)
# Out:
# {"findItemsByKeywordsResponse":[{"ack":["Success"],"version":["1.13.0"],"timestamp":["2018-12-21T13:57:52.347Z"],"searchResult":[{"@count":"6","item":[{"itemId":["382231636268"],"title":["Apple iPhone 7 32\\/128\\/256GB Factory Unlocked AT&T Sprint Verizon T-Mobile"],"globalId":["EBAY-US"],"subtitle":["US SELLER - 12 MONTH WARRANTY - FREE SHIPPING!"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32-128-256GB-Factory-Unlocked-AT-T-Sprint-Verizon-T-Mobile-\\/382231636268?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["30101"],"location":["Acworth,GA,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["false"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"234.99"}],"convertedCurrentPrice":[{"@currencyId":"USD","__value__":"234.99"}],"sellingState":["Active"],"timeLeft":["P22DT23H11M57S"]}],"listingInfo":[{"bestOfferEnabled":["false"],"buyItNowAvailable":["false"],"startTime":["2017-09-20T13:09:49.000Z"],"endTime":["2019-01-13T13:09:49.000Z"],"listingType":["FixedPrice"],"gift":["false"],"watchCount":["5868"]}],"returnsAccepted":["true"],"condition":[{"conditionId":["2500"],"conditionDisplayName":["Seller refurbished"]}],"isMultiVariationListing":["true"],"topRatedListing":["false"]},{"itemId":["352381131997"],"title":["Apple iPhone 7 GSM (Unlocked) Verizon AT&T TMobile Sprint 32GB 128GB 256GB"],"globalId":["EBAY-US"],"subtitle":["Free Shipping | 60 Day Warranty | #1 Customer Service"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-GSM-Unlocked-Verizon-AT-T-TMobile-Sprint-32GB-128GB-256GB-\\/352381131997?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["20879"],"location":["Gaithersburg,MD,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["true"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"249.89"}],"convertedCurrentPrice":[{"@currencyId":"USD","__value__":"249.89"}],"sellingState":["Active"],"timeLeft":["P21DT0H7M23S"]}],"listingInfo":[{"bestOfferEnabled":["false"],"buyItNowAvailable":["false"],"startTime":["2018-06-15T14:05:15.000Z"],"endTime":["2019-01-11T14:05:15.000Z"],"listingType":["FixedPrice"],"gift":["false"],"watchCount":["944"]}],"returnsAccepted":["true"],"condition":[{"conditionId":["2500"],"conditionDisplayName":["Seller refurbished"]}],"isMultiVariationListing":["true"],"topRatedListing":["true"]},{"itemId":["252764834267"],"title":["Apple iPhone 7 32GB GSM Unlocked Smartphone"],"globalId":["EBAY-US"],"subtitle":["TOP SELLER - FREE SHIPPING - FREE ACCESSORIES"],"primaryCategory":[{"categoryId":["9355"],"categoryName":["Cell Phones & Smartphones"]}],"galleryURL":["http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg"],"viewItemURL":["http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32GB-GSM-Unlocked-Smartphone-\\/252764834267?var=0"],"paymentMethod":["PayPal"],"autoPay":["true"],"postalCode":["11103"],"location":["Astoria,NY,USA"],"country":["US"],"shippingInfo":[{"shippingServiceCost":[{"@currencyId":"USD","__value__":"0.0"}],"shippingType":["Free"],"shipToLocations":["Worldwide"],"expeditedShipping":["true"],"oneDayShippingAvailable":["true"],"handlingTime":["1"]}],"sellingStatus":[{"currentPrice":[{"@currencyId":"USD","__value__":"279.99"}],"convertedCurrentPrice":[{"@currencyId":"USD","__value__":"279.99"}],"se ...

# %%
# Not very helpful, so let's turn that into a python dictionary and make it a little more human readable:
data = json.loads(cleaned_source)
pprint.pprint(data)
# Out:
# {'findItemsByKeywordsResponse': [{'ack': ['Success'],
#                                   'itemSearchURL': ['http:\\/\\/www.ebay.com\\/sch\\/i.html?_nkw=iPhone&_ddo=1&_ipg=6&_pgn=1'],
#                                   'paginationOutput': [{'entriesPerPage': ['6'],
#                                                         'pageNumber': ['1'],
#                                                         'totalEntries': ['19638893'],
#                                                         'totalPages': ['3273149']}],
#                                   'searchResult': [{'@count': '6',
#                                                     'item': [{'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Seller '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2500']}],
#                                                               'country': ['US'],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['382231636268'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-01-13T13:09:49.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['FixedPrice'],
#                                                                                'startTime': ['2017-09-20T13:09:49.000Z'],
#                                                                                'watchCount': ['5868']}],
#                                                               'location': ['Acworth,GA,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['30101'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '234.99'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '234.99'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P22DT23H11M57S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['false'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['US '
#                                                                            'SELLER '
#                                                                            '- '
#                                                                            '12 '
#                                                                            'MONTH '
#                                                                            'WARRANTY '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'SHIPPING!'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '7 '
#                                                                         '32\\/128\\/256GB '
#                                                                         'Factory '
#                                                                         'Unlocked '
#                                                                         'AT&T '
#                                                                         'Sprint '
#                                                                         'Verizon '
#                                                                         'T-Mobile'],
#                                                               'topRatedListing': ['false'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32-128-256GB-Factory-Unlocked-AT-T-Sprint-Verizon-T-Mobile-\\/382231636268?var=0']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Seller '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2500']}],
#                                                               'country': ['US'],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['352381131997'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-01-11T14:05:15.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['FixedPrice'],
#                                                                                'startTime': ['2018-06-15T14:05:15.000Z'],
#                                                                                'watchCount': ['944']}],
#                                                               'location': ['Gaithersburg,MD,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['20879'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '249.89'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '249.89'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P21DT0H7M23S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['true'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['Free '
#                                                                            'Shipping '
#                                                                            '| '
#                                                                            '60 '
#                                                                            'Day '
#                                                                            'Warranty '
#                                                                            '| '
#                                                                            '#1 '
#                                                                            'Customer '
#                                                                            'Service'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '7 GSM '
#                                                                         '(Unlocked) '
#                                                                         'Verizon '
#                                                                         'AT&T '
#                                                                         'TMobile '
#                                                                         'Sprint '
#                                                                         '32GB '
#                                                                         '128GB '
#                                                                         '256GB'],
#                                                               'topRatedListing': ['true'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-GSM-Unlocked-Verizon-AT-T-TMobile-Sprint-32GB-128GB-256GB-\\/352381131997?var=0']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Seller '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2500']}],
#                                                               'country': ['US'],
#                                                               'discountPriceInfo': [{'pricingTreatment': ['STP'],
#                                                                                      'soldOffEbay': ['false'],
#                                                                                      'soldOnEbay': ['false']}],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['252764834267'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-01-01T20:52:57.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['FixedPrice'],
#                                                                                'startTime': ['2017-02-10T20:52:57.000Z'],
#                                                                                'watchCount': ['10191']}],
#                                                               'location': ['Astoria,NY,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['11103'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '279.99'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '279.99'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P11DT6H55M5S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['true'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['TOP '
#                                                                            'SELLER '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'SHIPPING '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'ACCESSORIES'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '7 '
#                                                                         '32GB '
#                                                                         'GSM '
#                                                                         'Unlocked '
#                                                                         'Smartphone'],
#                                                               'topRatedListing': ['true'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32GB-GSM-Unlocked-Smartphone-\\/252764834267?var=0']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Seller '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2500']}],
#                                                               'country': ['US'],
#                                                               'discountPriceInfo': [{'originalRetailPrice': [{'@currencyId': 'USD',
#                                                                                                               '__value__': '799.99'}],
#                                                                                      'pricingTreatment': ['STP'],
#                                                                                      'soldOffEbay': ['false'],
#                                                                                      'soldOnEbay': ['false']}],
#                                                               'galleryURL': ['http:\\/\\/thumbs4.ebaystatic.com\\/pict\\/252764834267404000000004_4.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['252764834267'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-01-01T20:52:57.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['FixedPrice'],
#                                                                                'startTime': ['2017-02-10T20:52:57.000Z'],
#                                                                                'watchCount': ['3091']}],
#                                                               'location': ['Astoria,NY,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['11103'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '279.99'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '279.99'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P11DT6H55M5S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['true'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['TOP '
#                                                                            'SELLER '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'SHIPPING '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'ACCESSORIES'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '7 '
#                                                                         '32GB '
#                                                                         'GSM '
#                                                                         'Unlocked '
#                                                                         'Smartphone'],
#                                                               'topRatedListing': ['true'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32GB-GSM-Unlocked-Smartphone-\\/252764834267?var=551761488835']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Seller '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2500']}],
#                                                               'country': ['US'],
#                                                               'discountPriceInfo': [{'originalRetailPrice': [{'@currencyId': 'USD',
#                                                                                                               '__value__': '799.99'}],
#                                                                                      'pricingTreatment': ['STP'],
#                                                                                      'soldOffEbay': ['false'],
#                                                                                      'soldOnEbay': ['false']}],
#                                                               'galleryURL': ['http:\\/\\/thumbs4.ebaystatic.com\\/pict\\/252764834267404000000003_4.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['252764834267'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-01-01T20:52:57.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['FixedPrice'],
#                                                                                'startTime': ['2017-02-10T20:52:57.000Z'],
#                                                                                'watchCount': ['1081']}],
#                                                               'location': ['Astoria,NY,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['11103'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '279.99'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '279.99'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P11DT6H55M5S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['true'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['TOP '
#                                                                            'SELLER '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'SHIPPING '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'ACCESSORIES'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '7 '
#                                                                         '32GB '
#                                                                         'GSM '
#                                                                         'Unlocked '
#                                                                         'Smartphone'],
#                                                               'topRatedListing': ['true'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32GB-GSM-Unlocked-Smartphone-\\/252764834267?var=551761488834']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Seller '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2500']}],
#                                                               'country': ['US'],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['172900652413'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2018-12-26T10:47:39.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['FixedPrice'],
#                                                                                'startTime': ['2017-10-02T10:47:39.000Z'],
#                                                                                'watchCount': ['2402']}],
#                                                               'location': ['Acworth,GA,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['30101'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '199.99'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '199.99'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P4DT20H49M47S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['false'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['US '
#                                                                            'SELLER '
#                                                                            '- '
#                                                                            '12 '
#                                                                            'MONTH '
#                                                                            'WARRANTY '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'SHIPPING!'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '6s '
#                                                                         'Plus '
#                                                                         '16GB '
#                                                                         '32GB '
#                                                                         '64GB '
#                                                                         '128Gb '
#                                                                         'Factory '
#                                                                         'Unlocked '
#                                                                         'AT&T '
#                                                                         'Verizon '
#                                                                         'Sprint'],
#                                                               'topRatedListing': ['false'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-6s-Plus-16GB-32GB-64GB-128Gb-Factory-Unlocked-AT-T-Verizon-Sprint-\\/172900652413?var=0']}]}],
#                                   'timestamp': ['2018-12-21T13:57:52.347Z'],
#                                   'version': ['1.13.0']}]}

# %%
# Ok, now we want to parse this dictionary, retrieve only the 'title' and '__value__' from each search result and 
# save them to a new dictionary.
# First of, let's create an empty dictionary:
parsed = dict()
parsed2 = dict()
i = 0
# Now it's up to you to loop the 'data' dictionary, retrieve the elements, and add them to 
# the 'parsed' dictionary.

# %%
for result in data['findItemsByKeywordsResponse'][0]['searchResult'][0]['item']:
    if result.get('title') != None:
        title = result['title'][0]
        price = result['sellingStatus'][0]['currentPrice'][0]['__value__']
        parsed[title] = price
        # If there's products with the same name, python will update the dictionary instead of appending, resulting in fewer results
        # than expected (see the result of the first print below, only 4 results of the 6 available).
        # So an alternative if to save a dictionary of lists:
        temp = []
        temp.extend([title, price])
        parsed2[i] = temp
        i += 1
# first print
pprint.pprint(parsed)
print('-' * 30)
# second print
pprint.pprint(parsed2)
# Out:
# {'Apple iPhone 6s Plus 16GB 32GB 64GB 128Gb Factory Unlocked AT&T Verizon Sprint': '199.99',
#  'Apple iPhone 7 32GB GSM Unlocked Smartphone': '279.99',
#  'Apple iPhone 7 32\\/128\\/256GB Factory Unlocked AT&T Sprint Verizon T-Mobile': '234.99',
#  'Apple iPhone 7 GSM (Unlocked) Verizon AT&T TMobile Sprint 32GB 128GB 256GB': '249.89'}
# ------------------------------
# {0: ['Apple iPhone 7 32\\/128\\/256GB Factory Unlocked AT&T Sprint Verizon '
#      'T-Mobile',
#      '234.99'],
#  1: ['Apple iPhone 7 GSM (Unlocked) Verizon AT&T TMobile Sprint 32GB 128GB '
#      '256GB',
#      '249.89'],
#  2: ['Apple iPhone 7 32GB GSM Unlocked Smartphone', '279.99'],
#  3: ['Apple iPhone 7 32GB GSM Unlocked Smartphone', '279.99'],
#  4: ['Apple iPhone 7 32GB GSM Unlocked Smartphone', '279.99'],
#  5: ['Apple iPhone 6s Plus 16GB 32GB 64GB 128Gb Factory Unlocked AT&T Verizon '
#      'Sprint',
#      '199.99']}

# %%
# As extra info, imagine that you needed to save this file into a folder. It's always a good practice 
# to first check if the folder exists, and create it if necessary.
if not os.path.exists('result'):
    os.makedirs('result')
    
# Let's save the 'parsed' dictionary to a json file.
with open('result/search_results.json', 'w') as new_file:
    json.dump(parsed, new_file)
