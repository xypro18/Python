# %%
# This exercise will focus on parsing data in json format.
# We are accessing the Ebay API to perform a search for 'iphone', and we want to compile just some 
# of the returned information in another json file.
# First we'll import the necessary modules:
import json
from api import get_data # this is not a python module! It's our api.py file.
import os
import pprint # used to pretty print big python dictionaries

# Now we'll call the external API using a function in our api.py file
source = get_data("https://svcs.ebay.com/services/search/FindingService/v1?OPERATION-NAME=findItemsByKeywords&SERVICE-VERSION=1.0.0&RESPONSE-DATA-FORMAT=JSON&callback=_cb_findItemsByKeywords&REST-PAYLOAD&keywords=iPhone&paginationInput.entriesPerPage=6&GLOBAL-ID=EBAY-US&siteid=0&SECURITY-APPNAME=xotikota-pythonpo-PRD-87f3df848-3e35dfb4")
print(source)

# %%
# Let's clean the outcome and turn it into a valid json object:
x = str(source)
cleaned_source = x[:-2].replace("b'/**/_cb_findItemsByKeywords(", "")
# Let's get a glimpse of the outcome:
print(cleaned_source)

# %%
# Let's save the outcome into a json file, so that we can inspect it (you wouldn't do this on a production environment, but it helps a lot when developing):
with open("outcome.json", "w") as json_file:
    print(cleaned_source, file=json_file)

# %%
# Try to open the file. Whoa! The json has an error! Let's find it using an online tool: https://jsoneditoronline.org/
# We found the error, so let's fix it (not in our file, but in our cleaned_source variable):
cleaned_source = cleaned_source.replace('\\\\"', '')
print(cleaned_source)

# %%
# Not very easy to read, so let's turn that into a python dictionary and make it a little more human readable:
data = json.loads(cleaned_source)
pprint.pprint(data)
# Out:
# {'findItemsByKeywordsResponse': [{'ack': ['Success'],
#                                   'itemSearchURL': ['http:\\/\\/www.ebay.com\\/sch\\/i.html?_nkw=iPhone&_ddo=1&_ipg=6&_pgn=1'],
#                                   'paginationOutput': [{'entriesPerPage': ['6'],
#                                                         'pageNumber': ['1'],
#                                                         'totalEntries': ['22898012'],
#                                                         'totalPages': ['3816336']}],
#                                   'searchResult': [{'@count': '6',
#                                                     'item': [{'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Used'],
#                                                                              'conditionId': ['3000']}],
#                                                               'country': ['US'],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['153460727661'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-05-22T21:20:12.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['StoreInventory'],
#                                                                                'startTime': ['2019-04-22T21:20:12.000Z'],
#                                                                                'watchCount': ['373']}],
#                                                               'location': ['Louisville,KY,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['40291'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '125.0'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '125.0'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P19DT0H14M16S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['false'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['false'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['Fast '
#                                                                            'Shipping '
#                                                                            '- '
#                                                                            'Trusted '
#                                                                            'Seller '
#                                                                            '- '
#                                                                            '30 '
#                                                                            'Day '
#                                                                            'Free '
#                                                                            'Returns'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '6S  '
#                                                                         '16GB '
#                                                                         '64GB '
#                                                                         '128GB '
#                                                                         '(Unlocked) '
#                                                                         'Space '
#                                                                         'Gray, '
#                                                                         'Rose '
#                                                                         'Gold, '
#                                                                         'Silver, '
#                                                                         'Gold'],
#                                                               'topRatedListing': ['false'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-6S-16GB-64GB-128GB-Unlocked-Space-Gray-Rose-Gold-Silver-Gold-\\/153460727661?var=0']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Used'],
#                                                                              'conditionId': ['3000']}],
#                                                               'country': ['US'],
#                                                               'galleryURL': ['http:\\/\\/thumbs2.ebaystatic.com\\/pict\\/153460727661404000000001_1.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['153460727661'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-05-22T21:20:12.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['StoreInventory'],
#                                                                                'startTime': ['2019-04-22T21:20:12.000Z'],
#                                                                                'watchCount': ['65']}],
#                                                               'location': ['Louisville,KY,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['40291'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '160.0'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '160.0'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P19DT0H14M16S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['false'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['false'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['Fast '
#                                                                            'Shipping '
#                                                                            '- '
#                                                                            'Trusted '
#                                                                            'Seller '
#                                                                            '- '
#                                                                            '30 '
#                                                                            'Day '
#                                                                            'Free '
#                                                                            'Returns'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '6S  '
#                                                                         '16GB '
#                                                                         '64GB '
#                                                                         '128GB '
#                                                                         '(Unlocked) '
#                                                                         'Space '
#                                                                         'Gray, '
#                                                                         'Rose '
#                                                                         'Gold, '
#                                                                         'Silver, '
#                                                                         'Gold'],
#                                                               'topRatedListing': ['false'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-6S-16GB-64GB-128GB-Unlocked-Space-Gray-Rose-Gold-Silver-Gold-\\/153460727661?var=453413707543']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Manufacturer '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2000']}],
#                                                               'country': ['US'],
#                                                               'discountPriceInfo': [{'pricingTreatment': ['STP'],
#                                                                                      'soldOffEbay': ['false'],
#                                                                                      'soldOnEbay': ['false']}],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['264231737205'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-05-08T15:32:01.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['StoreInventory'],
#                                                                                'startTime': ['2019-03-09T15:32:01.000Z'],
#                                                                                'watchCount': ['3128']}],
#                                                               'location': ['Miami,FL,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['33179'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '209.99'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '209.99'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P4DT18H26M5S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['false'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['SHIPS '
#                                                                            '2 '
#                                                                            'DAY '
#                                                                            'FREE '
#                                                                            '+ '
#                                                                            'NEW '
#                                                                            'CHARGER '
#                                                                            '& '
#                                                                            'CABLE '
#                                                                            '+ '
#                                                                            '3 '
#                                                                            'MO '
#                                                                            'WARRANTY'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '7 '
#                                                                         '32GB '
#                                                                         'Unlocked '
#                                                                         'Excellent'],
#                                                               'topRatedListing': ['true'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-32GB-Unlocked-Excellent-\\/264231737205?var=0']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Used'],
#                                                                              'conditionId': ['3000']}],
#                                                               'country': ['US'],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['401466898078'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-05-21T18:17:01.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['StoreInventory'],
#                                                                                'startTime': ['2017-12-27T18:17:01.000Z'],
#                                                                                'watchCount': ['3960']}],
#                                                               'location': ['Clifton,NJ,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['07014'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '207.95'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '207.95'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P17DT21H11M5S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['false'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['false'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '7 '
#                                                                         'Factory '
#                                                                         'Unlocked '
#                                                                         '32GB '
#                                                                         '4G '
#                                                                         'LTE '
#                                                                         'iOS '
#                                                                         'WiFi '
#                                                                         'Smartphone'],
#                                                               'topRatedListing': ['true'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-Factory-Unlocked-32GB-4G-LTE-iOS-WiFi-Smartphone-\\/401466898078?var=0']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Seller '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2500']}],
#                                                               'country': ['US'],
#                                                               'discountPriceInfo': [{'pricingTreatment': ['STP'],
#                                                                                      'soldOffEbay': ['false'],
#                                                                                      'soldOnEbay': ['false']}],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['252945571859'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-05-08T20:04:44.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['FixedPrice'],
#                                                                                'startTime': ['2017-05-18T20:04:44.000Z'],
#                                                                                'watchCount': ['7159']}],
#                                                               'location': ['Astoria,NY,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['11103'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '309.99'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '309.99'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P4DT22H58M48S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['true'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['90 '
#                                                                            'DAY '
#                                                                            'WARRANTY '
#                                                                            '- '
#                                                                            'FREE '
#                                                                            'SHIPPING '
#                                                                            'AND '
#                                                                            'ACCESSORIES'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '7 '
#                                                                         'Plus '
#                                                                         '32GB '
#                                                                         'GSM '
#                                                                         'Unlocked '
#                                                                         'Smartphone'],
#                                                               'topRatedListing': ['true'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-7-Plus-32GB-GSM-Unlocked-Smartphone-\\/252945571859?var=0']},
#                                                              {'autoPay': ['true'],
#                                                               'condition': [{'conditionDisplayName': ['Manufacturer '
#                                                                                                       'refurbished'],
#                                                                              'conditionId': ['2000']}],
#                                                               'country': ['US'],
#                                                               'discountPriceInfo': [{'pricingTreatment': ['STP'],
#                                                                                      'soldOffEbay': ['false'],
#                                                                                      'soldOnEbay': ['false']}],
#                                                               'galleryURL': ['http:\\/\\/thumbs1.ebaystatic.com\\/pict\\/04040_0.jpg'],
#                                                               'globalId': ['EBAY-US'],
#                                                               'isMultiVariationListing': ['true'],
#                                                               'itemId': ['264234670292'],
#                                                               'listingInfo': [{'bestOfferEnabled': ['false'],
#                                                                                'buyItNowAvailable': ['false'],
#                                                                                'endTime': ['2019-05-10T14:12:14.000Z'],
#                                                                                'gift': ['false'],
#                                                                                'listingType': ['StoreInventory'],
#                                                                                'startTime': ['2019-03-11T14:12:14.000Z'],
#                                                                                'watchCount': ['1385']}],
#                                                               'location': ['Miami,FL,USA'],
#                                                               'paymentMethod': ['PayPal'],
#                                                               'postalCode': ['33179'],
#                                                               'primaryCategory': [{'categoryId': ['9355'],
#                                                                                    'categoryName': ['Cell '
#                                                                                                     'Phones '
#                                                                                                     '& '
#                                                                                                     'Smartphones']}],
#                                                               'returnsAccepted': ['true'],
#                                                               'sellingStatus': [{'convertedCurrentPrice': [{'@currencyId': 'USD',
#                                                                                                             '__value__': '354.99'}],
#                                                                                  'currentPrice': [{'@currencyId': 'USD',
#                                                                                                    '__value__': '354.99'}],
#                                                                                  'sellingState': ['Active'],
#                                                                                  'timeLeft': ['P6DT17H6M18S']}],
#                                                               'shippingInfo': [{'expeditedShipping': ['true'],
#                                                                                 'handlingTime': ['1'],
#                                                                                 'oneDayShippingAvailable': ['false'],
#                                                                                 'shipToLocations': ['Worldwide'],
#                                                                                 'shippingServiceCost': [{'@currencyId': 'USD',
#                                                                                                          '__value__': '0.0'}],
#                                                                                 'shippingType': ['Free']}],
#                                                               'subtitle': ['SHIPS '
#                                                                            '2 '
#                                                                            'DAY '
#                                                                            'FREE '
#                                                                            '+ '
#                                                                            'NEW '
#                                                                            'CHARGER '
#                                                                            '& '
#                                                                            'CABLE '
#                                                                            '+ '
#                                                                            '3 '
#                                                                            'MO '
#                                                                            'WARRANTY'],
#                                                               'title': ['Apple '
#                                                                         'iPhone '
#                                                                         '8 '
#                                                                         '64GB '
#                                                                         'Unlocked '
#                                                                         'Excellent'],
#                                                               'topRatedListing': ['true'],
#                                                               'viewItemURL': ['http:\\/\\/www.ebay.com\\/itm\\/Apple-iPhone-8-64GB-Unlocked-Excellent-\\/264234670292?var=0']}]}],
#                                   'timestamp': ['2019-05-03T21:05:56.174Z'],
#                                   'version': ['1.13.0']}]}

# %%
# Ok, now we want to parse this dictionary, retrieve only the 'title' and '__value__' from each search result and 
# save them to a new dictionary.
# First of, let's create an empty dictionary:
parsed = dict()

# Now it's up to you to loop the 'data' dictionary, retrieve the elements, and add them to 
# the 'parsed' dictionary. Remember, if you have your data in a dictionary it means that you can dump it at any 
# time to json format.

# %%
# As extra info, imagine that you needed to save this dictionary into a file inside a folder. 
# It's always a good practice to first check if the folder exists, and create it if necessary.
if not os.path.exists('result'):
    os.makedirs('result')
    
# Let's save the 'parsed' dictionary to a json file.
with open('result/search_results.json', 'w') as new_file:
    json.dump(parsed, new_file)
